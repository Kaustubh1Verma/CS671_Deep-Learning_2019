# %%
import tensorflow as tf
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# Q3 API
from layers import dense

# %%
epochs = 120
batch_size = 50
learning_rate = 0.005

# %%
mnist = np.load('mnist.npz')

# %%
# split training data (60,000) into 55,000 for train and 5,000 for validate images
train, x_test = mnist['x_train'], mnist['x_test']
train = train.reshape((60000, 784))/255
x_train = train[:55000].copy()
x_val = train[55000:].copy()
x_test = x_test.reshape((10000, 784))/255
# labels
train_labels = mnist['y_train']
y_train = np.eye(10)[train_labels[:55000]]
y_val = np.eye(10)[train_labels[55000:]]
y_test = np.eye(10)[mnist['y_test']]

# %%
# input
x_p = tf.placeholder(tf.float32, [None, 784])
# output
y_p = tf.placeholder(tf.float32, [None, 10])

# %%
hidden1 = dense(x=x_p, in_length=784, neurons=150, activation=tf.nn.relu, layer_name='Layer_1')
hidden2 = dense(x=hidden1, in_length=150, neurons=50, activation=tf.nn.relu, layer_name='Layer_2')
output = dense(x=hidden2, in_length=50, neurons=10, activation=tf.nn.softmax, layer_name='Layer_Output')
y_clipped = tf.clip_by_value(output, 1e-10, 0.9999999)
cross_entropy = -tf.reduce_mean(tf.reduce_sum(y_p * tf.log(y_clipped)+ (1 - y_p) * tf.log(1 - y_clipped), axis=1))
optimiser = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cross_entropy)

# %%
labels = tf.argmax(y_p, 1)
predictions = tf.argmax(output, 1)

# %%
acc, acc_op = tf.metrics.accuracy(labels, predictions)

# %%
conmat = tf.confusion_matrix(labels, predictions)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    avg_loss = []
    validate_accuracy = []
    total_batches = x_train.shape[0] // batch_size
    
    # Training
    for e in range(epochs):
        avg_loss.append(0.0)
        for b in range(total_batches):
            start = b*batch_size
            end = (b+1)*batch_size
            batch = sess.run([optimiser, cross_entropy], 
                     feed_dict={x_p: x_train[start:end], y_p: y_train[start:end]})
            avg_loss[e] += batch[1] / total_batches
        
        # Validation
        accuracy = sess.run(acc_op,
                 feed_dict={x_p: x_val, y_p: y_val})
        validate_accuracy.append(accuracy)
        print("Epoch: {:2d}".format(e + 1), "train_loss =", "{:.4f}".format(avg_loss[e]), "validate_accuracy =", "{:.4f}".format(validate_accuracy[e]))
        
    # Testing
    test_accuracy, confusion_mat = sess.run([acc_op, conmat],
                    feed_dict={x_p:x_test, y_p:y_test})
    
    print('Testing Accuracy:', test_accuracy)
    print('Confusion Matrix:', confusion_mat)
    
    tf.io.write_graph(sess.graph_def, 'graphs/', 'mnist-v3.pbtxt')
# Out:
# Epoch:  1 train_loss = 27.9837 validate_accuracy = 0.4566
# Epoch:  2 train_loss = 19.4796 validate_accuracy = 0.5082
# Epoch:  3 train_loss = 16.6576 validate_accuracy = 0.5481
# Epoch:  4 train_loss = 14.2228 validate_accuracy = 0.5758
# Epoch:  5 train_loss = 13.0617 validate_accuracy = 0.5981
# Epoch:  6 train_loss = 12.4685 validate_accuracy = 0.6167
# Epoch:  7 train_loss = 11.9798 validate_accuracy = 0.6314
# Epoch:  8 train_loss = 11.8110 validate_accuracy = 0.6426
# Epoch:  9 train_loss = 11.6039 validate_accuracy = 0.6507
# Epoch: 10 train_loss = 11.3002 validate_accuracy = 0.6578
# Epoch: 11 train_loss = 11.1190 validate_accuracy = 0.6642
# Epoch: 12 train_loss = 10.8917 validate_accuracy = 0.6701
# Epoch: 13 train_loss = 10.9124 validate_accuracy = 0.6752
# Epoch: 14 train_loss = 10.8708 validate_accuracy = 0.6792
# Epoch: 15 train_loss = 10.6612 validate_accuracy = 0.6825
# Epoch: 16 train_loss = 10.6462 validate_accuracy = 0.6862
# Epoch: 17 train_loss = 10.5486 validate_accuracy = 0.6891
# Epoch: 18 train_loss = 10.5050 validate_accuracy = 0.6920
# Epoch: 19 train_loss = 10.4567 validate_accuracy = 0.6946
# Epoch: 20 train_loss = 10.4009 validate_accuracy = 0.6973
# Epoch: 21 train_loss = 10.3567 validate_accuracy = 0.6997
# Epoch: 22 train_loss = 10.1694 validate_accuracy = 0.7021
# Epoch: 23 train_loss = 10.0754 validate_accuracy = 0.7042
# Epoch: 24 train_loss = 10.2149 validate_accuracy = 0.7061
# Epoch: 25 train_loss = 10.0953 validate_accuracy = 0.7080
# Epoch: 26 train_loss = 10.0540 validate_accuracy = 0.7098
# Epoch: 27 train_loss = 10.1248 validate_accuracy = 0.7113
# Epoch: 28 train_loss = 10.0726 validate_accuracy = 0.7129
# Epoch: 29 train_loss = 10.0842 validate_accuracy = 0.7143
# Epoch: 30 train_loss = 9.8938 validate_accuracy = 0.7154
# Epoch: 31 train_loss = 9.8490 validate_accuracy = 0.7168
# Epoch: 32 train_loss = 9.7983 validate_accuracy = 0.7179
# Epoch: 33 train_loss = 9.8188 validate_accuracy = 0.7189
# Epoch: 34 train_loss = 9.6956 validate_accuracy = 0.7200
# Epoch: 35 train_loss = 9.7407 validate_accuracy = 0.7210
# Epoch: 36 train_loss = 9.7331 validate_accuracy = 0.7221
# Epoch: 37 train_loss = 9.6278 validate_accuracy = 0.7232
# Epoch: 38 train_loss = 9.6631 validate_accuracy = 0.7242
# Epoch: 39 train_loss = 9.6092 validate_accuracy = 0.7252
# Epoch: 40 train_loss = 9.5860 validate_accuracy = 0.7260
# Epoch: 41 train_loss = 9.5540 validate_accuracy = 0.7268
# Epoch: 42 train_loss = 9.5812 validate_accuracy = 0.7277
# Epoch: 43 train_loss = 9.5423 validate_accuracy = 0.7285
# Epoch: 44 train_loss = 9.5241 validate_accuracy = 0.7293
# Epoch: 45 train_loss = 9.5699 validate_accuracy = 0.7300
# Epoch: 46 train_loss = 9.5434 validate_accuracy = 0.7308
# Epoch: 47 train_loss = 9.4827 validate_accuracy = 0.7315
# Epoch: 48 train_loss = 9.4430 validate_accuracy = 0.7322
# Epoch: 49 train_loss = 9.4932 validate_accuracy = 0.7328
# Epoch: 50 train_loss = 9.4701 validate_accuracy = 0.7335
# Epoch: 51 train_loss = 9.3726 validate_accuracy = 0.7341
# Epoch: 52 train_loss = 9.3659 validate_accuracy = 0.7348
# Epoch: 53 train_loss = 9.3248 validate_accuracy = 0.7353
# Epoch: 54 train_loss = 9.3211 validate_accuracy = 0.7359
# Epoch: 55 train_loss = 9.3195 validate_accuracy = 0.7365
# Epoch: 56 train_loss = 9.3919 validate_accuracy = 0.7369
# Epoch: 57 train_loss = 9.2981 validate_accuracy = 0.7373
# Epoch: 58 train_loss = 9.2673 validate_accuracy = 0.7378
# Epoch: 59 train_loss = 9.4225 validate_accuracy = 0.7383
# Epoch: 60 train_loss = 9.2458 validate_accuracy = 0.7388
# Epoch: 61 train_loss = 9.2289 validate_accuracy = 0.7392
# Epoch: 62 train_loss = 9.2925 validate_accuracy = 0.7396
# Epoch: 63 train_loss = 9.2188 validate_accuracy = 0.7400
# Epoch: 64 train_loss = 9.2690 validate_accuracy = 0.7404
# Epoch: 65 train_loss = 9.2501 validate_accuracy = 0.7409
# Epoch: 66 train_loss = 9.2267 validate_accuracy = 0.7413
# Epoch: 67 train_loss = 9.2401 validate_accuracy = 0.7416
# Epoch: 68 train_loss = 9.1694 validate_accuracy = 0.7420
# Epoch: 69 train_loss = 9.1506 validate_accuracy = 0.7424
# Epoch: 70 train_loss = 9.1003 validate_accuracy = 0.7428
# Epoch: 71 train_loss = 9.0790 validate_accuracy = 0.7431
# Epoch: 72 train_loss = 9.0752 validate_accuracy = 0.7435
# Epoch: 73 train_loss = 9.0616 validate_accuracy = 0.7438
# Epoch: 74 train_loss = 9.0145 validate_accuracy = 0.7442
# Epoch: 75 train_loss = 9.2014 validate_accuracy = 0.7445
# Epoch: 76 train_loss = 9.0613 validate_accuracy = 0.7449
# Epoch: 77 train_loss = 9.1324 validate_accuracy = 0.7452
# Epoch: 78 train_loss = 8.9773 validate_accuracy = 0.7456
# Epoch: 79 train_loss = 9.1307 validate_accuracy = 0.7459
# Epoch: 80 train_loss = 8.9798 validate_accuracy = 0.7462
# Epoch: 81 train_loss = 8.9749 validate_accuracy = 0.7466
# Epoch: 82 train_loss = 8.9827 validate_accuracy = 0.7468
# Epoch: 83 train_loss = 9.0078 validate_accuracy = 0.7471
# Epoch: 84 train_loss = 8.9882 validate_accuracy = 0.7474
# Epoch: 85 train_loss = 8.9329 validate_accuracy = 0.7476
# Epoch: 86 train_loss = 8.9622 validate_accuracy = 0.7478
# Epoch: 87 train_loss = 8.9616 validate_accuracy = 0.7481
# Epoch: 88 train_loss = 8.8926 validate_accuracy = 0.7483
# Epoch: 89 train_loss = 8.9415 validate_accuracy = 0.7486
# Epoch: 90 train_loss = 8.8917 validate_accuracy = 0.7488
# Epoch: 91 train_loss = 8.9573 validate_accuracy = 0.7491
# Epoch: 92 train_loss = 8.9278 validate_accuracy = 0.7493
# Epoch: 93 train_loss = 8.8933 validate_accuracy = 0.7495
# Epoch: 94 train_loss = 9.0094 validate_accuracy = 0.7497
# Epoch: 95 train_loss = 8.9250 validate_accuracy = 0.7500
# Epoch: 96 train_loss = 8.9577 validate_accuracy = 0.7502
# Epoch: 97 train_loss = 8.9260 validate_accuracy = 0.7504
# Epoch: 98 train_loss = 8.9451 validate_accuracy = 0.7506
# Epoch: 99 train_loss = 8.9431 validate_accuracy = 0.7508
# Epoch: 100 train_loss = 8.9633 validate_accuracy = 0.7510
# Epoch: 101 train_loss = 8.9311 validate_accuracy = 0.7512
# Epoch: 102 train_loss = 8.8400 validate_accuracy = 0.7514
# Epoch: 103 train_loss = 8.9411 validate_accuracy = 0.7516
# Epoch: 104 train_loss = 8.9155 validate_accuracy = 0.7518
# Epoch: 105 train_loss = 8.8733 validate_accuracy = 0.7520
# Epoch: 106 train_loss = 8.8706 validate_accuracy = 0.7522
# Epoch: 107 train_loss = 8.8502 validate_accuracy = 0.7524
# Epoch: 108 train_loss = 8.8290 validate_accuracy = 0.7526
# Epoch: 109 train_loss = 8.8538 validate_accuracy = 0.7528
# Epoch: 110 train_loss = 8.8241 validate_accuracy = 0.7529
# Epoch: 111 train_loss = 8.8705 validate_accuracy = 0.7531
# Epoch: 112 train_loss = 8.7939 validate_accuracy = 0.7533
# Epoch: 113 train_loss = 8.8542 validate_accuracy = 0.7535
# Epoch: 114 train_loss = 8.8124 validate_accuracy = 0.7536
# Epoch: 115 train_loss = 8.7982 validate_accuracy = 0.7538
# Epoch: 116 train_loss = 8.7990 validate_accuracy = 0.7540
# Epoch: 117 train_loss = 8.8062 validate_accuracy = 0.7542
# Epoch: 118 train_loss = 8.7877 validate_accuracy = 0.7543
# Epoch: 119 train_loss = 8.7734 validate_accuracy = 0.7545
# Epoch: 120 train_loss = 8.7418 validate_accuracy = 0.7546
# Testing Accuracy: 0.75487375
# Confusion Matrix: [[   0    0  161   24    6  399    0  314   55   21]
#  [   0 1120    5    5    0    2    0    1    2    0]
#  [   0    0  964   22    4    1    0   20   18    3]
#  [   0    0    8  977    2    5    0    5    9    4]
#  [   0    1    8    0  944    0    0    2    5   22]
#  [   0    1    4   26    1  829    0    5   16   10]
#  [   0    7  430    9  145  111    0    8  230   18]
#  [   0    6   10    7    6    2    0  976    6   15]
#  [   0    0    4   17    3    4    0   10  929    7]
#  [   0    6    1   10   15    4    0   16   10  947]]

# %%
plt.xlabel('Epoch')
plt.ylabel('Cross Entropy Loss')
plt.plot(avg_loss[None:])
plt.show()

# %%
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.plot(validate_accuracy)
plt.show()

# %%
np.savetxt('mnistv3-conmat.txt', confusion_mat, fmt='%4d', delimiter=' & ', newline='\\\\\\hline\n')

# %%
True_positives = np.diag(confusion_mat)
False_positives = np.sum(confusion_mat, axis=1) - True_positives
False_negatives = np.sum(confusion_mat, axis=0) - True_positives
Precision = True_positives / (True_positives + False_positives)
print("Precision:", Precision)
Recall = True_positives / (True_positives + False_negatives)
print("\nRecall:", Recall)
F_scores = (2*Precision*Recall) / (Recall+Precision)
print("\nF_scores:", F_scores)
# Out:
# Precision: [0.         0.98678414 0.93410853 0.96732673 0.96130346 0.9293722
#  0.         0.94941634 0.95379877 0.93855302]
#
# Recall: [       nan 0.98159509 0.60438871 0.89061076 0.8383659  0.61090641
#         nan 0.7192336  0.72578125 0.90448902]
#
# F_scores: [       nan 0.98418278 0.73391702 0.92738491 0.89563567 0.73721654
#         nan 0.81844864 0.82431233 0.92120623]
# /opt/miniconda3/envs/python_3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
plt.plot(Precision, label='Precision')
plt.plot(Recall, label='Recall')
plt.plot(F_scores, label='F Scores')
plt.ylabel('Score')
plt.xlabel('Class')
plt.legend()
plt.show()

# %%
plt.xlabel('Class')
plt.ylabel('Precision')
plt.plot(Precision)
plt.show()

# %%
plt.xlabel('Class')
plt.ylabel('Recall')
plt.plot(Recall)
plt.show()

# %%
plt.xlabel('Class')
plt.ylabel('F Scores')
plt.plot(F_scores)
plt.show()
